# %% [markdown]
# <div style="overflow: hidden;">
#     <div style="float: right; margin-left: 20px;">
#         <img src="https://i.ibb.co/XD2jnTN/Untitled-design.png" alt="Music Genre classification" width="400"/>
#     </div>
#     <div style="margin-top: 40px; font-family: 'Arial', sans-serif;">
#         <span style="color:#8B322C; font-size: 24px; font-family: 'Courier New', sans-serif; font-weight: 600;">Music Genre classification 🎶 </span><br>
#
#
# - <span style="color:#8B322C; font-size: 17px; font-family: 'Courier New', sans-serif; font-weight:600;">Done by : Lujain yousef. </span><br>
#
# - <span style="color:#8B322C; font-size: 17px; font-family: 'Courier New', sans-serif; font-weight:600;">Columns: </span><br>
#     - **popularity**:
#    This column likely represents the popularity of a song, usually measured by metrics like number of streams, downloads, or views. It indicates how well-received or widely listened to a song is.
#
#    - **acousticness**:
#    This column measures the degree of acousticness of a song, indicating how much of the sound is derived from acoustic instruments as opposed to electronic ones. A higher value suggests a more acoustic sound.
#
#    - **danceability**:
#    This column measures how suitable a song is for dancing based on various musical elements such as rhythm, tempo, and beat strength. Higher values indicate songs that are easier to dance to.
#
#    - **duration_ms**:
#    This column represents the duration of the song in milliseconds, indicating how long the song lasts from start to finish.
#
#    - **energy**:
#    This column measures the energy level of a song. Songs with high energy are typically fast, loud, and noisy, while songs with low energy are often slow and calm.
#
#    - **instrumentalness**:
#    This column measures the presence of instrumental sounds in a song. A high instrumentalness value suggests that the song is predominantly instrumental, while a low value indicates the presence of vocals.
#
#    - **liveness**:
#    This column measures the presence of a live audience in the recording. A high value suggests that the song was performed live, while a low value indicates a studio recording.
#
#    - **loudness**:
#    This column represents the overall loudness of the song in decibels (dB). It indicates the volume level of the song.
#
#    - **speechiness**:
#    This column measures the presence of spoken words in the song, such as rap or spoken word segments. Higher values suggest a greater presence of speech-like elements.
#
#    - **tempo**:
#     This column represents the tempo of the song, measured in beats per minute (BPM). It indicates the speed or pace of the song.
#
#    - **valence**:
#     This column measures the overall positivity or happiness of the song. Higher values indicate a more positive or happy mood, while lower values suggest a more negative or sad mood.
#
#    - **genre**:
#     This column represents the genre or category of the song. It indicates the style or classification of music the song belongs to, such as pop, rock, jazz, etc.
#     </div>
# </div>

# %%
import pandas as pd
df = pd.read_csv('music_clean (1).csv',index_col='Unnamed: 0')
df
# Out:
#        popularity  acousticness  danceability  duration_ms  energy  \
# 36506        60.0      0.896000         0.726     214547.0  0.1770
# 37591        63.0      0.003840         0.635     190448.0  0.9080
# 37658        59.0      0.000075         0.352     456320.0  0.9560
# 36060        54.0      0.945000         0.488     352280.0  0.3260
# 35710        55.0      0.245000         0.667     273693.0  0.6470
# ...           ...           ...           ...          ...     ...
# 44501        57.0      0.972000         0.193     208040.0  0.0329
# 25114        56.0      0.005790         0.939     144453.0  0.3730
# 46896        54.0      0.016100         0.739     238339.0  0.5390
# 45135        62.0      0.326000         0.515     286707.0  0.5050
# 18960        42.0      0.029500         0.291     194679.0  0.5980
#
#        instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 36506          0.000002    0.1160   -14.824       0.0353   92.934   0.6180
# ...

# %%
df.dtypes
# Out:
# popularity          float64
# acousticness        float64
# danceability        float64
# duration_ms         float64
# energy              float64
# instrumentalness    float64
# liveness            float64
# loudness            float64
# speechiness         float64
# tempo               float64
# valence             float64
# genre                 int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 36506 to 18960
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   popularity        1000 non-null   float64
#  1   acousticness      1000 non-null   float64
#  2   danceability      1000 non-null   float64
#  3   duration_ms       1000 non-null   float64
#  4   energy            1000 non-null   float64
#  5   instrumentalness  1000 non-null   float64
#  6   liveness          1000 non-null   float64
#  7   loudness          1000 non-null   float64
#  8   speechiness       1000 non-null   float64
#  9   tempo             1000 non-null   float64
#  10  valence           1000 non-null   float64
#  11  genre             1000 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 101.6 KB

# %%
df.describe()
# Out:
#         popularity  acousticness  danceability   duration_ms       energy  \
# count  1000.000000   1000.000000   1000.000000  1.000000e+03  1000.000000
# mean     51.660000      0.258649      0.542602  2.172204e+05     0.636464
# std      14.028585      0.307494      0.160322  1.175582e+05     0.237789
# min       0.000000      0.000003      0.062400 -1.000000e+00     0.002510
# 25%      43.750000      0.013275      0.444000  1.806562e+05     0.485750
# 50%      54.000000      0.116000      0.548500  2.163000e+05     0.676500
# 75%      62.000000      0.426500      0.657000  2.605025e+05     0.822500
# max      82.000000      0.996000      0.950000  1.617333e+06     0.995000
#
#        instrumentalness     liveness     loudness  speechiness        tempo  \
# count       1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean           0.137289     0.199993    -8.253305     0.077879   120.368400
# ...

# %%
from sklearn.feature_selection import VarianceThreshold

# Calculate variances
variances = df.var()

# Analyze variances
print("Variance summary:")
print(variances.describe())

# Plot histogram of variances (optional)
import matplotlib.pyplot as plt
plt.hist(variances, bins=20)
plt.xlabel('Variance')
plt.ylabel('Frequency')
plt.title('Histogram of Variances')
plt.show()

# Select a threshold (e.g., based on visual inspection of histogram or summary statistics)
threshold = 0.005

# Apply VarianceThreshold
sel = VarianceThreshold(threshold=threshold)
sel.fit(df)

# Get selected features
selected_features = df.columns[sel.get_support()]

# Print selected features
print("Selected features:")
print(selected_features)

# Evaluate feature selection (e.g., by comparing model performance before and after)
# Out:
# Variance summary:
# count    1.200000e+01
# mean     1.151660e+09
# std      3.989468e+09
# min      8.001418e-03
# 25%      4.884264e-02
# 50%      8.804796e-02
# 75%      6.915807e+01
# max      1.381992e+10
# dtype: float64
# Selected features:
# Index(['popularity', 'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
#        'valence', 'genre'],
#       dtype='object')

# %%
import seaborn as sns 
sns.pairplot(df)
# Out:
# C:\Users\yluja\Documents\adult.csv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import numpy as np
cmap = sns.diverging_palette(h_neg=10, h_pos=240, as_cmap=True)
corr = df.corr()
mask = np.triu(np.ones_like(corr,dtype=bool))
sns.heatmap(corr,mask=mask,
           center=0,cmap=cmap,annot=True,fmt='.2f')
# Out:
# <Axes: >

# %%
corr_df = reduced_df.corr().abs()
mask = np.triu(np.ones_like(corr_df,dtype=bool))
tri_df = corr_df.mask(mask) 
to_drop = [c for c in tri_df.columns if any(tri_df[c]>0.8)] # 0.8
print(to_drop)
df = df.drop(to_drop,axis=1)
df.shape
# Out:
# []
# (1000, 12)

# %%
from sklearn.feature_selection import VarianceThreshold
sel = VarianceThreshold(threshold=0.005 )
sel.fit(df)

mask = sel.get_support()
df = df.loc[:,mask]
df.shape
# Out:
# (1000, 12)

# %%
df.columns
# Out:
# Index(['popularity', 'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
#        'valence', 'genre'],
#       dtype='object')

# %%
X = df.drop(columns='genre')
y = df['genre']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
y.value_counts() # it's balanced
# Out:
# genre
# 1    500
# 0    500
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
y_test.value_counts().plot.pie(autopct='%.2f', colors=['#ffb6c1', "#93154d"])
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
# Instantiate rf
rf = RandomForestClassifier()
param_grid = {
    'clf__n_estimators': np.arange(50, 200, 50),  # Number of trees in the forest
    'clf__max_depth': np.arange(3, 10, 1),  # Maximum depth of the tree
    'clf__min_samples_leaf': np.arange(1, 10, 1)  # Minimum number of samples required to be at a leaf node
}

# %%
from sklearn.preprocessing import StandardScaler
pipeline = Pipeline([
    ("st_scaler", StandardScaler()),
    ("clf",rf)  
])

# %%
randomized_rf = RandomizedSearchCV(estimator=pipeline,
                  param_distributions=param_grid,
                  n_iter=10,
                  scoring='accuracy',
                  n_jobs=4,
                  cv=10,
                  refit=True,
                  return_train_score=True)

randomized_rf.fit(X_train,y_train)

pred = randomized_rf.predict(X_test)

accuracy_score(y_test,pred)
# Out:
# 0.85

# %%
import matplotlib.pyplot as plt
rf.fit(X_train,y_train)
# Create a pd.Series of features importances
importances = pd.Series(data= rf.feature_importances_,
                       index= X.columns)

# Sort importances
importances_sorted = importances.sort_values()

# Draw a horizontal barplot of importances_sorted
importances_sorted.plot(kind='barh', color='lightgreen')
plt.title('Features Importances')
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import RandomizedSearchCV

# Define the parameter grid for DecisionTreeClassifier
param_grid = {
    'clf__max_depth': np.arange(3, 10),  # Maximum depth of the tree
    'clf__min_samples_split': np.arange(2, 10),  # Minimum number of samples required to split an internal node
    'clf__min_samples_leaf': np.arange(1, 10)  # Minimum number of samples required to be at a leaf node
}

dt = DecisionTreeClassifier(random_state=42)
# Define the pipeline with StandardScaler and DecisionTreeClassifier
pipeline = Pipeline([
    ("st_scaler", StandardScaler()),
    ("clf", dt)  
])

# Instantiate RandomizedSearchCV
randomized_search = RandomizedSearchCV(
    estimator=pipeline,
    param_distributions=param_grid,
    n_iter=10,
    scoring='accuracy',
    cv=10,
    n_jobs=4,
    refit=True,
    return_train_score=True
)

# Fit RandomizedSearchCV to the data
randomized_search.fit(X_train, y_train)

# Predict on the test set
pred = randomized_search.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8333333333333334

# %%
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score

# Define the parameter grid for XGBoost
param_grid = {
    'n_estimators': [10, 50, 100, 200],  # Number of boosting rounds
    'max_depth': [3, 5, 7, 9],  # Maximum depth of a tree
    'learning_rate': [0.01, 0.1, 0.3, 0.5],  # Learning rate
    'min_child_weight': [1, 3, 5],  # Minimum sum of instance weight needed in a child
    'subsample': [0.6, 0.8, 1.0],  # Subsample ratio of the training instances
    'colsample_bytree': [0.6, 0.8, 1.0],  # Subsample ratio of columns when constructing each tree
    'gamma': [0,0.1, 0.2, 0.3],  # Minimum loss reduction required to make a further partition on a leaf node of the tree
}

# Instantiate XGBoost classifier
model = xgb.XGBClassifier(objective='binary:logistic', seed=123)

# Instantiate RandomizedSearchCV
randomized_search = RandomizedSearchCV(
    estimator=model,
    param_distributions=param_grid,
    n_iter=10,
    scoring='accuracy',
    cv=10,
    n_jobs=4,
    refit=True,
    return_train_score=True
)

# Fit RandomizedSearchCV to the data
randomized_search.fit(X_train, y_train)

# Predict on the test set
preds = randomized_search.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, preds)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8466666666666667

# %%
import numpy as np
import xgboost as xgb
from sklearn.datasets import load_iris
from sklearn.model_selection import RandomizedSearchCV, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier


# Define a list of candidate models
models = [
    ('RandomForest', RandomForestClassifier()),
    ('DecisionTree', DecisionTreeClassifier()),
    ('XGBoost', xgb.XGBClassifier(objective='binary:logistic', seed=123))
]

# Iterate over models
for name, model in models:
    # Define parameter grid for the model (if applicable)
    param_grid = {}
    if name == 'RandomForest':
        param_grid = {
            'n_estimators': np.arange(50, 200, 50),
            'max_depth': np.arange(3, 10),
            'min_samples_split': np.arange(2, 10)
        }
    elif name == 'DecisionTree':
        param_grid = {
            'max_depth': np.arange(3, 10),
            'min_samples_split': np.arange(2, 10)
        }
    elif name == 'XGBoost':
        param_grid = {
            'n_estimators': [50, 100, 150],
            'max_depth': [3, 5, 7],
            'learning_rate': [0.01, 0.1, 0.3],
            'min_child_weight': [1, 3, 5],
            'subsample': [0.6, 0.8, 1.0],
            'colsample_bytree': [0.6, 0.8, 1.0],
            'gamma': [0, 0.1, 0.2]
        }
    
    # Set up RandomizedSearchCV for hyperparameter tuning
    randomized_search = RandomizedSearchCV(
        estimator=model,
        param_distributions=param_grid,
        n_iter=10,
        scoring='accuracy',
        cv=5,
        n_jobs=-1
    )
    
    # Perform nested cross-validation
    cv_scores = cross_val_score(randomized_search, X, y, cv=5)
    
    # Print the mean and standard deviation of cross-validation scores
    print(f'{name}: Mean Accuracy: {cv_scores.mean()}, Std: {cv_scores.std()}')
# Out:
# RandomForest: Mean Accuracy: 0.877, Std: 0.025019992006393633
# DecisionTree: Mean Accuracy: 0.8550000000000001, Std: 0.022135943621178676
# XGBoost: Mean Accuracy: 0.875, Std: 0.030000000000000023

# %%
from sklearn.metrics import confusion_matrix

# Define the predicted labels for each model (replace with actual predictions)
pred_rf = rf.fit(X_train,y_train).predict(X_test)
pred_dt = dt.fit(X_train,y_train).predict(X_test)
pred_xgb = model.fit(X_train,y_train).predict(X_test)

# Calculate confusion matrices for each model
cm_rf = confusion_matrix(y_test, pred_rf)
cm_dt = confusion_matrix(y_test, pred_dt)
cm_xgb = confusion_matrix(y_test, pred_xgb)

# Print confusion matrices
print("RandomForest Confusion Matrix:")
colors = ["#f1c1d1", "#eaa2bb", "#e080a8", "#d95c8f", "#c44b7e", "#b5386e", "#a3265d", "#93154d", "#82033e", "#71012f"]
# Plot the confusion matrix using a heatmap with the custom color palette
plt.figure(figsize=(5, 4))
sns.heatmap(cm_rf , annot=True, cmap=colors, fmt='g', xticklabels=[0, 1], yticklabels=[0, 1])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()


print("\nDecisionTree Confusion Matrix:")
plt.figure(figsize=(5, 4))
sns.heatmap(cm_dt , annot=True, cmap=colors, fmt='g', xticklabels=[0, 1], yticklabels=[0, 1])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("\nXGBoost Confusion Matrix:")
plt.figure(figsize=(5, 4))
sns.heatmap(cm_xgb , annot=True, cmap=colors, fmt='g', xticklabels=[0, 1], yticklabels=[0, 1])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# RandomForest Confusion Matrix:
# DecisionTree Confusion Matrix:
# XGBoost Confusion Matrix:
